# %%
#import necessary libraries
import numpy as np
import pandas as pd
import os
from sklearn import preprocessing
from sklearn.impute import SimpleImputer

# %%
#create 4 dataframes for each file
df1 = pd.read_csv('/Users/wesleywong/Desktop/SchoolFolders/Spring 2022/CPSC4310notgit/CPSC4310/MLP/MLP2/rawdata/dailyActivity_merged.csv')
df2 = pd.read_csv('/Users/wesleywong/Desktop/SchoolFolders/Spring 2022/CPSC4310notgit/CPSC4310/MLP/MLP2/rawdata/sleepdata_2.csv')
df3 = pd.read_csv('/Users/wesleywong/Desktop/SchoolFolders/Spring 2022/CPSC4310notgit/CPSC4310/MLP/MLP2/rawdata/sleepdata.csv')
df4 = pd.read_csv('/Users/wesleywong/Desktop/SchoolFolders/Spring 2022/CPSC4310notgit/CPSC4310/MLP/MLP2/rawdata/sleepDay_merged.csv')

# %%
#data cleaning for df1
df1 = df1.drop(columns=['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'SedentaryMinutes', 'TotalDistance', 'TrackerDistance', 'VeryActiveDistance', 'ModeratelyActiveDistance', 'LightActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes'])
df1.head(20)
# Out:
#    ActivityDate  TotalSteps  Calories
# 0     4/12/2016       13162      1985
# 1     4/13/2016       10735      1797
# 2     4/14/2016       10460      1776
# 3     4/15/2016        9762      1745
# 4     4/16/2016       12669      1863
# 5     4/17/2016        9705      1728
# 6     4/18/2016       13019      1921
# 7     4/19/2016       15506      2035
# 8     4/20/2016       10544      1786
# 9     4/21/2016        9819      1775
# 10    4/22/2016       12764      1827
# 11    4/23/2016       14371      1949
# 12    4/24/2016       10039      1788
# 13    4/25/2016       15355      2013
# 14    4/26/2016       13755      1970
# 15    4/27/2016       18134      2159
# 16    4/28/2016       13154      1898
# 17    4/29/2016       11181      1837
# 18    4/30/2016       14673      1947
# 19     5/1/2016       10602      1820

# %%
#dataframe 2 cleaning
df2 = df2.drop(columns=['Heart rate (bpm)', 'Notes', 'Mood', 'City', 'Air Pressure (Pa)', ])
df2 = df2.drop(columns=['Window start', 'Window stop'])
df2 = df2.drop(columns=['Weather temperature (°C)', 'Weather type'])

df2.head(20)
# Out:
#                   Start                  End Sleep Quality Regularity  \
# 0   2019-05-12 23:26:13  2019-05-13 06:11:03           60%         0%
# 1   2019-05-13 22:10:31  2019-05-14 06:10:42           73%         0%
# 2   2019-05-14 21:43:00  2019-05-15 06:10:41           86%        96%
# 3   2019-05-15 23:11:51  2019-05-16 06:13:59           77%        92%
# 4   2019-05-16 23:12:13  2019-05-17 06:20:32           78%        94%
# 5   2019-05-19 01:25:12  2019-05-19 08:43:11           72%        80%
# 6   2019-05-20 22:41:13  2019-05-21 06:22:58           73%        58%
# 7   2019-05-21 22:39:27  2019-05-22 06:00:55           78%        77%
# 8   2019-05-22 22:36:59  2019-05-23 06:03:59           84%        98%
# 9   2019-05-23 23:15:23  2019-05-24 06:33:47           88%        95%
# 10  2019-05-26 00:21:00  2019-05-26 08:19:28           71%        83%
# 11  2019-05-26 22:49:24  2019-05-27 06:09:41           73%        73%
# ...

# %%
#dataframe 3 cleaning
#df3 = df3.drop(columns=['Activity (steps)'])
values = df3[["Heart rate"]]
imputer = SimpleImputer()
transformed_values = imputer.fit_transform(values)
df3[['Heart rate']] = pd.DataFrame(transformed_values)

df3.dropna(subset='Wake up')

df3.head(20)
# Out:
#                   Start                  End Sleep quality Time in bed  \
# 0   2014-12-29 22:57:49  2014-12-30 07:30:13          100%        8:32
# 1   2014-12-30 21:17:50  2014-12-30 21:33:54            3%        0:16
# 2   2014-12-30 22:42:49  2014-12-31 07:13:31           98%        8:30
# 3   2014-12-31 22:31:01  2015-01-01 06:03:01           65%        7:32
# 4   2015-01-01 22:12:10  2015-01-02 04:56:35           72%        6:44
# 5   2015-01-03 00:34:57  2015-01-03 07:47:23           83%        7:12
# 6   2015-01-04 00:23:06  2015-01-04 07:37:09           78%        7:14
# 7   2015-01-04 21:34:44  2015-01-05 04:53:34           78%        7:18
# 8   2015-01-05 21:32:25  2015-01-06 05:00:03           69%        7:27
# 9   2015-01-06 21:24:56  2015-01-07 05:00:02           74%        7:35
# 10  2015-01-07 20:59:58  2015-01-08 06:19:20           81%        9:19
# 11  2015-01-08 22:58:18  2015-01-09 06:14:58           88%        7:16
# ...

# %%
#dataframe 4 cleaning
df4 = df4.drop(columns=['Id', 'TotalSleepRecords'])
df4.head(20)
# Out:
#                  SleepDay  TotalMinutesAsleep  TotalTimeInBed
# 0   4/12/2016 12:00:00 AM                 327             346
# 1   4/13/2016 12:00:00 AM                 384             407
# 2   4/15/2016 12:00:00 AM                 412             442
# 3   4/16/2016 12:00:00 AM                 340             367
# 4   4/17/2016 12:00:00 AM                 700             712
# 5   4/19/2016 12:00:00 AM                 304             320
# 6   4/20/2016 12:00:00 AM                 360             377
# 7   4/21/2016 12:00:00 AM                 325             364
# 8   4/23/2016 12:00:00 AM                 361             384
# 9   4/24/2016 12:00:00 AM                 430             449
# 10  4/25/2016 12:00:00 AM                 277             323
# 11  4/26/2016 12:00:00 AM                 245             274
# 12  4/28/2016 12:00:00 AM                 366             393
# 13  4/29/2016 12:00:00 AM                 341             354
# ...

# %%
#to_csv
os.makedirs('/Users/wesleywong/Desktop/SchoolFolders/Spring 2022/CPSC4310notgit/CPSC4310/MLP/MLP2/input', exist_ok=True)  
df1.to_csv('/Users/wesleywong/Desktop/SchoolFolders/Spring 2022/CPSC4310notgit/CPSC4310/MLP/MLP2/input/dailyActivityCleaned.csv')
df2.to_csv('/Users/wesleywong/Desktop/SchoolFolders/Spring 2022/CPSC4310notgit/CPSC4310/MLP/MLP2/input/sleepdata2Cleaned.csv')   
df3.to_csv('/Users/wesleywong/Desktop/SchoolFolders/Spring 2022/CPSC4310notgit/CPSC4310/MLP/MLP2/input/sleepdataCleaned.csv')
df4.to_csv('/Users/wesleywong/Desktop/SchoolFolders/Spring 2022/CPSC4310notgit/CPSC4310/MLP/MLP2/input/sleepDayCleaned.csv')
